# %%
'hello'
# Out:
# 'hello'

# %%
"world"
# Out:
# 'world'

# %%
'this is also a string'
# Out:
# 'this is also a string'

# %%
" I'm going on a run "
# Out:
# " I'm going on a run "

# %%
print("hello")
# Out:
# hello

# %%
print("hello world one")
print("hello world two")
# Out:
# hello world one
# hello world two

# %%
print('hello \t world')
# Out:
# hello 	 world

# %%
len("hello")
# Out:
# 5

# %%
len("i am")
# Out:
# 4

# %%
mystring = "Hello World"

# %%
mystring
# Out:
# 'Hello World'

# %%
mystring[0]
# Out:
# 'H'

# %%
mystring[8]
# Out:
# 'r'

# %%
mystring[9]
# Out:
# 'l'

# %%
mystring
# Out:
# 'Hello World'

# %%
mystring[-3]
# Out:
# 'r'

# %%
mystring = 'abcdeghijk'

# %%
mystring
# Out:
# 'abcdeghijk'

# %%
mystring[2:]
# Out:
# 'cdeghijk'

# %%
mystring[:3]
# Out:
# 'abc'

# %%
mystring
# Out:
# 'abcdeghijk'

# %%
mystring[3:1]
# Out:
# ''

# %%
mystring[3:6]
# Out:
# 'deg'

# %%
mystring[1:3]
# Out:
# 'bc'

# %%
mystring[1:5:-1]
# Out:
# ''

# %%
mystring[::2]
# Out:
# 'acehj'

# %%
mystring[::-1]
# Out:
# 'kjihgedcba'

# %% [markdown]
# %% Immutability

# %%
name = "Sam"

# %%
#name[0] = 'P'

# %%
last_letters = name[1:]

# %%
last_letters
# Out:
# 'am'

# %%
'P' + last_letters
# Out:
# 'Pam'

# %%
x = 'Hello World'

# %%
x = x + ' it is beautiful outside'

# %%
x
# Out:
# 'Hello World it is beautiful outside'

# %%
letter = 'z'

# %%
letter * 10
# Out:
# 'zzzzzzzzzz'

# %%
2 + 3
# Out:
# 5

# %%
'2' + '3'
# Out:
# '23'

# %%
x = 'Hello World'

# %%
x.upper()
# Out:
# 'HELLO WORLD'

# %%
x
# Out:
# 'Hello World'

# %%
x.lower()
# Out:
# 'hello world'

# %%
x.split()
# Out:
# ['Hello', 'World']

# %%
x
# Out:
# 'Hello World'

# %%
x = ' Ho this is a string'

# %%
x.split()
# Out:
# ['Ho', 'this', 'is', 'a', 'string']

# %%
x.split('i')
# Out:
# [' Ho th', 's ', 's a str', 'ng']
